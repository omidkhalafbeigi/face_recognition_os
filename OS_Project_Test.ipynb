# %%
from PIL import Image
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cnn = tf.keras.models.load_model('drive/My Drive/FaceRecognition_Model_16')

# %%
img = tf.keras.preprocessing.image.load_img('drive/My Drive/europe_guy.jpeg', target_size=(128, 128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FCD6D9FF5F8>

# %%
img = tf.keras.preprocessing.image.img_to_array(img)

# %%
img /= 255

# %%
cnn.predict(x=img.reshape(1, 128, 128, 3))
# Out:
# array([[2.3529109e-20]], dtype=float32)
